# %%
# 1st method

# %% [markdown]
# <img src="image/PasswordImage.jpg"/>

# %%
# 2nd method

# %%
from IPython import display
display.Image("image/PasswordImage.jpg")

# %%
# 3rd method

# %% [markdown]
# ![Password](image/PasswordImage.jpg)

# %%
# 4th method

# %% [markdown]
# ![PasswordImage.jpg](attachment:PasswordImage.jpg)
